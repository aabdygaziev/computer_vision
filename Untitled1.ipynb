# %%
# importing packages
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('in_NYC.jpeg',0)

# %%
plt.imshow(img,cmap='gray')
plt.show()

# %%
#type of the img file
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
img.shape
# Out:
# (768, 1024)

# %%
# %matplotlib inline
plt.imshow(img)
plt.show()

# %%
# to rotate the picture I need to know width and height of the picture
height, width  = img.shape[0:2]

# %%
img.shape[0:2]
# Out:
# (768, 1024)

# %%
height
# Out:
# 768

# %%
# cv2.getRotationMatrix2D(center, angle, scale)

rotationMatrix = cv2.getRotationMatrix2D((width/2, height/2), 270, 1)

# %%
rotatedImage = cv2.warpAffine(img, rotationMatrix, (width, height))

# %%
# %matplotlib inline
plt.imshow(rotatedImage)
plt.show()
